# %% [raw]
# from monkeylearn import MonkeyLearn
# ml = MonkeyLearn('acb42a14d51e14f942c6824e0d41241cd54cca4a')
# model_id = 'cl_pi3C7JiL'
# result = ml.classifiers.classify(model_id, list(data["Comment"].to_json()))

# %%
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from bs4 import BeautifulSoup
import time
import requests
import json
import itertools

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\91897\AppData\Local\Programs\Python\Python310\python.exe

# %% [raw]
# api key AIzaSyD_gsAPrY1q_JpwQQBBwLntfmwyn3Aiq_A - youtube
# monkeylearn api key - acb42a14d51e14f942c6824e0d41241cd54cca4a

# %%
# setting link for youtube google api and extrating the html page as text
#AIzaSyBekbSE51NBYQpR7ZIPJAI4utsVBJ-SpwI
link = 'https://www.googleapis.com/youtube/v3/search?key=AIzaSyBekbSE51NBYQpR7ZIPJAI4utsVBJ-SpwI&channelId=UCPg2V8RXeuM3NZ60e-kT7Zw&part=snippet,id&order=date&maxResults=50'
response = requests.get(link).text

temp = json.loads(response)
# print(json.dumps(temp, indent = 2, ensure_ascii = False))

#listing all the items
temp1 = temp["items"] #list

Id = []

#separating all the video ID's
for i in temp1:
    if i["id"]["kind"] == 'youtube#video':
        Id.append({"id":i["id"]["videoId"]})

#if there is a next page going there and getting the video ID's until there is no next page
while True:
    try:
        if temp["nextPageToken"] is None or temp["nextPageToken"] == "":
            break
        else:
            nxtpg = temp["nextPageToken"]
            link = 'https://www.googleapis.com/youtube/v3/search?pageToken='+nxtpg+'&part=snippet&maxResults=25&order=relevance&q=site%3Ayoutube.com&topicId=%2Fm%2F02vx4&key=AIzaSyAGg1syggKzB6PtW8DvK6wyCol4UD0yTgw'
            response = requests.get(link).text

            temp = json.loads(response)
            temp1 = temp["items"]
            for i in temp1:
                if i["id"]["kind"] == 'youtube#video':
                    Id.append({"id":i["id"]["videoId"]})
    except:
        break
    

print(json.dumps(Id, indent = 2, ensure_ascii = False))

# %%
#saving all the extratcted video ID's so that API need not be run again
P_Id = [
  {
    "id": "YFcbf6LJ0i8"
  },
  {
    "id": "UOHxpXRu264"
  },
  {
    "id": "pHWCt2IkXmE"
  },
  {
    "id": "gX_e62K7hrM"
  },
  {
    "id": "S--_b6fqy-I"
  },
  {
    "id": "Upy5iEFujgo"
  },
  {
    "id": "kGaYFMBBLHI"
  },
  {
    "id": "JOT7npZCss4"
  },
  {
    "id": "_PZcif6MOBU"
  },
  {
    "id": "A2ToRMgiCnc"
  },
  {
    "id": "utjbE3DAVsI"
  },
  {
    "id": "5DkT-8kVqys"
  },
  {
    "id": "dYeUNdMtBdY"
  },
  {
    "id": "thXEUDyfWto"
  },
  {
    "id": "cCxCDDI9UAs"
  },
  {
    "id": "dqqfvfvrnDk"
  },
  {
    "id": "P_hyzH99TOk"
  },
  {
    "id": "ARpCuC2RBwQ"
  },
  {
    "id": "vWNRkmVjraI"
  },
  {
    "id": "iZnFjbopz9o"
  },
  {
    "id": "ZhVmnxd9fOc"
  },
  {
    "id": "2Vwt4SUhRek"
  },
  {
    "id": "tS6xEeSvjz8"
  },
  {
    "id": "bEwtH02x_is"
  },
  {
    "id": "zM0EP2nkT3E"
  },
  {
    "id": "tO5ZfbDDVY8"
  },
  {
    "id": "h89CCinoX6E"
  },
  {
    "id": "IehKSx2Kmak"
  },
  {
    "id": "a1bzdlvpJe4"
  },
  {
    "id": "9ZwQV0vmLXA"
  },
  {
    "id": "v6IcLOP1OXM"
  },
  {
    "id": "bsY_ECo0bYA"
  },
  {
    "id": "j7ucxBaHLjM"
  },
  {
    "id": "JEp3hy3RqGc"
  },
  {
    "id": "BjNzfTrE6Go"
  },
  {
    "id": "74AKE-m8OWM"
  },
  {
    "id": "cey790sTUkM"
  },
  {
    "id": "3KSQipsuVjg"
  },
  {
    "id": "EFhPCVEYpHM"
  },
  {
    "id": "MxP8BB3bAGE"
  },
  {
    "id": "7osd7I8SjLQ"
  },
  {
    "id": "qu6yRlpBbPo"
  },
  {
    "id": "2q_tA8v5l1Y"
  },
  {
    "id": "ACgrmzoxqaM"
  },
  {
    "id": "7ZncQCU9H6w"
  },
  {
    "id": "ZR08W4_0SBk"
  },
  {
    "id": "sxlFgMVVNuU"
  },
  {
    "id": "iwxgbP6SIi8"
  }]

# %%
P_Id
# Out:
# [{'id': 'YFcbf6LJ0i8'},
#  {'id': 'UOHxpXRu264'},
#  {'id': 'pHWCt2IkXmE'},
#  {'id': 'gX_e62K7hrM'},
#  {'id': 'S--_b6fqy-I'},
#  {'id': 'Upy5iEFujgo'},
#  {'id': 'kGaYFMBBLHI'},
#  {'id': 'JOT7npZCss4'},
#  {'id': '_PZcif6MOBU'},
#  {'id': 'A2ToRMgiCnc'},
#  {'id': 'utjbE3DAVsI'},
#  {'id': '5DkT-8kVqys'},
#  {'id': 'dYeUNdMtBdY'},
#  {'id': 'thXEUDyfWto'},
#  {'id': 'cCxCDDI9UAs'},
#  {'id': 'dqqfvfvrnDk'},
#  {'id': 'P_hyzH99TOk'},
#  {'id': 'ARpCuC2RBwQ'},
#  {'id': 'vWNRkmVjraI'},
#  {'id': 'iZnFjbopz9o'},
#  {'id': 'ZhVmnxd9fOc'},
#  {'id': '2Vwt4SUhRek'},
#  {'id': 'tS6xEeSvjz8'},
#  {'id': 'bEwtH02x_is'},
#  {'id': 'zM0EP2nkT3E'},
#  {'id': 'tO5ZfbDDVY8'},
#  {'id': 'h89CCinoX6E'},
#  {'id': 'IehKSx2Kmak'},
#  {'id': 'a1bzdlvpJe4'},
#  {'id': '9ZwQV0vmLXA'},
#  {'id': 'v6IcLOP1OXM'},
#  {'id': 'bsY_ECo0bYA'},
#  {'id': 'j7ucxBaHLjM'},
#  {'id': 'JEp3hy3RqGc'},
#  {'id': 'BjNzfTrE6Go'},
#  {'id': '74AKE-m8OWM'},
#  {'id': 'cey790sTUkM'},
#  {'id': '3KSQipsuVjg'},
#  {'id': 'EFhPCVEYpHM'},
#  {'id': 'MxP8BB3bAGE'},
#  {'id': '7osd7I8SjLQ'},
#  {'id': 'qu6yRlpBbPo'},
#  {'id': '2q_tA8v5l1Y'},
#  {'id': 'ACgrmzoxqaM'},
#  {'id': '7ZncQCU9H6w'},
#  {'id': 'ZR08W4_0SBk'},
#  {'id': 'sxlFgMVVNuU'},
#  {'id': 'iwxgbP6SIi8'}]

# %%
print(Id[2])
# Out:
# {'id': 'UOHxpXRu264'}

# %%
#setting api key 
api_key = "AIzaSyBekbSE51NBYQpR7ZIPJAI4utsVBJ-SpwI" # Insert your Api key here.

from googleapiclient.discovery import build
youtube = build('youtube', 'v3', developerKey=api_key)

import pandas as pd

box = [['Name', 'Comment', 'Time', 'Likes', 'Reply Count']]

code_lang = P_Id
# sql_vids = pd.DataFrame([])

#going through each video id and getting the comments, if there is a next page for comments it goes there too to retreive comments
for id_code in code_lang:
#     print(id_code)
    def scrape_comments_with_replies():
        data = youtube.commentThreads().list(part='snippet', videoId=id_code['id'], maxResults='100', textFormat="plainText").execute()
        
        for i in data["items"]:
            name = i["snippet"]['topLevelComment']["snippet"]["authorDisplayName"]
            comment = i["snippet"]['topLevelComment']["snippet"]["textDisplay"]
            published_at = i["snippet"]['topLevelComment']["snippet"]['publishedAt']
            likes = i["snippet"]['topLevelComment']["snippet"]['likeCount']
            replies = i["snippet"]['totalReplyCount']
            
            box.append([name, comment, published_at, likes, replies])
            
            totalReplyCount = i["snippet"]['totalReplyCount']
            
            if totalReplyCount > 0:
                
                parent = i["snippet"]['topLevelComment']["id"]
                
                data2 = youtube.comments().list(part='snippet', maxResults='100', parentId=parent,
                                            textFormat="plainText").execute()
                
                for i in data2["items"]:
                    name = i["snippet"]["authorDisplayName"]
                    comment = i["snippet"]["textDisplay"]
                    published_at = i["snippet"]['publishedAt']
                    likes = i["snippet"]['likeCount']
                    replies = ""

                    box.append([name, comment, published_at, likes, replies])

        while ("nextPageToken" in data):
            
            data = youtube.commentThreads().list(part='snippet', videoId=id_code['id'], pageToken=data["nextPageToken"],
                                             maxResults='100', textFormat="plainText").execute()
                                             
            for i in data["items"]:
                name = i["snippet"]['topLevelComment']["snippet"]["authorDisplayName"]
                comment = i["snippet"]['topLevelComment']["snippet"]["textDisplay"]
                published_at = i["snippet"]['topLevelComment']["snippet"]['publishedAt']
                likes = i["snippet"]['topLevelComment']["snippet"]['likeCount']
                replies = i["snippet"]['totalReplyCount']

                box.append([name, comment, published_at, likes, replies])

                totalReplyCount = i["snippet"]['totalReplyCount']

                if totalReplyCount > 0:
                    
                    parent = i["snippet"]['topLevelComment']["id"]

                    data2 = youtube.comments().list(part='snippet', maxResults='100', parentId=parent,
                                                    textFormat="plainText").execute()

                    for i in data2["items"]:
                        name = i["snippet"]["authorDisplayName"]
                        comment = i["snippet"]["textDisplay"]
                        published_at = i["snippet"]['publishedAt']
                        likes = i["snippet"]['likeCount']
                        replies = ''

                        box.append([name, comment, published_at, likes, replies])
                        
        # saves the scrapped comment in a datagrame then pushes it to a csv file
        df = pd.DataFrame({'Name': [i[0] for i in box], 'Comment': [i[1] for i in box], 'Time': [i[2] for i in box],
                       'Likes': [i[3] for i in box], 'Reply Count': [i[4] for i in box]})
        
        sql_vids = pd.DataFrame([])

        sql_vids = sql_vids.append(df, ignore_index = True)

        sql_vids.to_csv('youtube-comments.csv', index=False, header=False)
    try:
        scrape_comments_with_replies()
    except:
        continue
data = pd.read_csv(r'youtube-comments.csv',lineterminator='\n')

data
# Out:
# C:\Users\91897\AppData\Local\Temp\ipykernel_30320\2806838463.py:85: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sql_vids = sql_vids.append(df, ignore_index = True)
#                   Name                                            Comment  \
# 0    black bron gaming  robocraze web site per koi 1000pcs 5mm led nhi...
# 1           LORD ULTRA  Your web site real or fake please tell your se...
# 2            Robocraze  Hello Sir! We are a 100% genuine website, and ...
# 3                Najah  Sir plzz send the mini dron making parts plzz ...
# 4            Robocraze                                      Thank you! :)
# ..                 ...                                                ...
# 280     Mani Sathappan              Good tutorial. Keep up the good work.
# 281          Robocraze  Thank you, we are happy that you liked the vid...
# 282        Prince Mahi                                Keep it up bro ❤️❤️
# 283          Robocraze                              Glad you liked it! :)
# 284       Moinak Ghosh          Thanks!! Stay tuned for more such content
#
#                      Time  Likes Reply Count\r
# 0    2023-01-18T17:18:19Z      0           0\r
# 1    2022-05-11T11:23:36Z      1           1\r
# 2    2022-05-11T13:14:30Z      0            \r
# 3    2022-04-29T10:40:48Z      0           1\r
# 4    2022-05-11T13:15:38Z      0            \r
# ..                    ...    ...           ...
# 280  2021-04-16T06:17:42Z      0           1\r
# 281  2021-04-23T12:19:27Z      0            \r
# 282  2021-04-13T19:34:50Z      1           2\r
# 283  2022-04-05T08:35:14Z      0            \r
# 284  2021-04-22T06:20:09Z      0            \r
#
# [285 rows x 5 columns]

# %%
#cleaning the text and having only alphanumeric characters
def cleanTxt(text):
    text = re.sub(r'[^\w]', ' ', text)
    return text


data['Comment'] = data['Comment'].apply(cleanTxt)

# %%
#getting subjectivity and polarity to predict the sentiment of the comment
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# get polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

#Columns
data['Subjectivity'] = data['Comment'].apply(getSubjectivity)
data['Polarity'] = data['Comment'].apply(getPolarity)

data
# Out:
#                   Name                                            Comment  \
# 0    black bron gaming  robocraze web site per koi 1000pcs 5mm led nhi...
# 1           LORD ULTRA  Your web site real or fake please tell your se...
# 2            Robocraze  Hello Sir  We are a 100  genuine website  and ...
# 3                Najah  Sir plzz send the mini dron making parts plzz ...
# 4            Robocraze                                      Thank you
# ..                 ...                                                ...
# 280     Mani Sathappan              Good tutorial  Keep up the good work
# 281          Robocraze  Thank you  we are happy that you liked the vid...
# 282        Prince Mahi                                Keep it up bro
# 283          Robocraze                              Glad you liked it
# 284       Moinak Ghosh          Thanks   Stay tuned for more such content
#
#                      Time  Likes Reply Count\r  Subjectivity  Polarity
# 0    2023-01-18T17:18:19Z      0           0\r      0.500000 -0.500000
# 1    2022-05-11T11:23:36Z      1           1\r      1.000000 -0.750000
# 2    2022-05-11T13:14:30Z      0            \r      0.633333  0.183333
# 3    2022-04-29T10:40:48Z      0           1\r      0.000000  0.000000
# 4    2022-05-11T13:15:38Z      0            \r      0.000000  0.000000
# ..                    ...    ...           ...           ...       ...
# 280  2021-04-16T06:17:42Z      0           1\r      0.600000  0.700000
# 281  2021-04-23T12:19:27Z      0            \r      0.751515  0.512121
# 282  2021-04-13T19:34:50Z      1           2\r      0.000000  0.000000
# 283  2022-04-05T08:35:14Z      0            \r      0.900000  0.550000
# 284  2021-04-22T06:20:09Z      0            \r      0.400000  0.233333
#
# [285 rows x 7 columns]

# %%
# allWords = ' '.join( [cmts for cmts in data['Comment']])
# wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allWords)

# %%
#depending on polarity comment is categorized to be positive negative or neutral
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score > 0:
        return 'Positive'
    else:
        return 'Neutral'
    
data['TextBlob Analysis'] = data['Polarity'].apply(getAnalysis)

# %% [raw]
# from transformers import pipeline
# classifier = pipeline("text-classification")

# %% [raw]
# # using hugging face - pipeline to predict the sentiment
# text = data["Comment"]
# text
# ans = []
# for i in text:
#     j = classifier(i)
#     print(i,j[0]["label"])
#     ans.append(j[0]["label"])
# data['HuggingFace Analysis'] = ans

# %%
data
# Out:
#                   Name                                            Comment  \
# 0    black bron gaming  robocraze web site per koi 1000pcs 5mm led nhi...
# 1           LORD ULTRA  Your web site real or fake please tell your se...
# 2            Robocraze  Hello Sir  We are a 100  genuine website  and ...
# 3                Najah  Sir plzz send the mini dron making parts plzz ...
# 4            Robocraze                                      Thank you
# ..                 ...                                                ...
# 280     Mani Sathappan              Good tutorial  Keep up the good work
# 281          Robocraze  Thank you  we are happy that you liked the vid...
# 282        Prince Mahi                                Keep it up bro
# 283          Robocraze                              Glad you liked it
# 284       Moinak Ghosh          Thanks   Stay tuned for more such content
#
#                      Time  Likes Reply Count\r  Subjectivity  Polarity  \
# 0    2023-01-18T17:18:19Z      0           0\r      0.500000 -0.500000
# 1    2022-05-11T11:23:36Z      1           1\r      1.000000 -0.750000
# 2    2022-05-11T13:14:30Z      0            \r      0.633333  0.183333
# 3    2022-04-29T10:40:48Z      0           1\r      0.000000  0.000000
# 4    2022-05-11T13:15:38Z      0            \r      0.000000  0.000000
# ..                    ...    ...           ...           ...       ...
# 280  2021-04-16T06:17:42Z      0           1\r      0.600000  0.700000
# 281  2021-04-23T12:19:27Z      0            \r      0.751515  0.512121
# 282  2021-04-13T19:34:50Z      1           2\r      0.000000  0.000000
# 283  2022-04-05T08:35:14Z      0            \r      0.900000  0.550000
# 284  2021-04-22T06:20:09Z      0            \r      0.400000  0.233333
#
#     TextBlob Analysis
# 0            Negative
# 1            Negative
# 2            Positive
# 3             Neutral
# 4             Neutral
# ..                ...
# 280          Positive
# 281          Positive
# 282           Neutral
# 283          Positive
# 284          Positive
#
# [285 rows x 8 columns]

# %% [raw]
# data["TextBlob Analysis"]=data["TextBlob Analysis"].str.capitalize()
# data["HuggingFace Analysis"] = data["HuggingFace Analysis"].str.capitalize()

# %%
data["TextBlob Analysis"].value_counts()
# Out:
# Positive    178
# Neutral      90
# Negative     17
# Name: TextBlob Analysis, dtype: int64

# %% [raw]
# data["HuggingFace Analysis"].value_counts()

# %% [raw]
# #counting the number of difference between the 2 types of analysis
# c = 0
# for (i,j) in zip(data["TextBlob Analysis"],data["HuggingFace Analysis"]):
#     if i != j:
#         c+=1
#
# c
